# %%
#5
area = (1/2) * 10 * 12
print(area)
# Out:
# 60.0

# %%
import math

# %%
#6
r = 5
h = 3
sa = (2*math.pi*r*h) + (2*math.pi*(r**2))
print(sa)
# Out:
# 251.32741228718345

# %%
#7
x_1 = 3
x_2 = 5
y_1 = 4
y_2 = 9
m = (y_2-y_1)/(x_2 - x_1)
print(m)
# Out:
# 2.5

# %%
#8
x_1 = 3
x_2 = 5
y_1 = 4
y_2 = 9
distance = math.sqrt((math.pow((x_2-x_1), 2)) + (math.pow((y_2-y_1), 2)))
print(distance)
# Out:
# 5.385164807134504

# %%
#9
print(math.factorial(6))
# Out:
# 720

# %%
#10
for i in range(1500, 2011):
    if (i % 4 ==0 and i % 100 != 0) or (i % 400 == 0):
        print(i)
# Out:
# 1504
# 1508
# 1512
# 1516
# 1520
# 1524
# 1528
# 1532
# 1536
# 1540
# 1544
# 1548
# 1552
# 1556
# 1560
# 1564
# 1568
# 1572
# 1576
# 1580
# 1584
# 1588
# 1592
# 1596
# 1600
# 1604
# 1608
# 1612
# 1616
# 1620
# 1624
# 1628
# 1632
# 1636
# 1640
# 1644
# 1648
# 1652
# 1656
# 1660
# 1664
# 1668
# 1672
# 1676
# 1680
# 1684
# 1688
# 1692
# 1696
# 1704
# 1708
# 1712
# 1716
# 1720
# 1724
# 1728
# 1732
# 1736
# 1740
# 1744
# 1748
# 1752
# 1756
# 1760
# 1764
# 1768
# 1772
# 1776
# 1780
# 1784
# 1788
# 1792
# 1796
# 1804
# 1808
# 1812
# 1816
# 1820
# 1824
# 1828
# 1832
# 1836
# 1840
# 1844
# 1848
# 1852
# 1856
# 1860
# 1864
# 1868
# 1872
# 1876
# 1880
# 1884
# 1888
# 1892
# 1896
# 1904
# 1908
# 1912
# 1916
# 1920
# 1924
# 1928
# 1932
# 1936
# 1940
# 1944
# 1948
# 1952
# 1956
# 1960
# 1964
# 1968
# 1972
# 1976
# 1980
# 1984
# 1988
# 1992
# 1996
# 2000
# 2004
# 2008

# %%
#11
number = [0,1]
sum = 0
for i in number:
    sum = sum + (math.factorial(4*i) * (1103 + (26390*i)))/(((math.factorial(i))**4) * ((396)**(4*i)))
result = (2*math.sqrt(2)/9801)*sum
print(1/result)
# Out:
# 3.1415926535897936

# %%
#11
math.pi
# Out:
# 3.141592653589793

# %%
#12
result = (math.exp(2) - math.exp(-2))/2
print(result)
# Out:
# 3.626860407847019

# %%
#12
math.sinh(2)
# Out:
# 3.6268604078470186

# %%
#13
list = [math.pi, math.pi/2, math.pi/4, math.pi/6]
sum = 0
for i in list:
    sum = (math.sin(i))**2 + (math.cos(i))**2
    print(sum)
# Out:
# 1.0
# 1.0
# 1.0
# 1.0

# %%
#14
print(math.sin(math.radians(87)))
# Out:
# 0.9986295347545738

# %%
#15
print(math.sni(math.pi))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(math.sni(math.pi))
#
# AttributeError: module 'math' has no attribute 'sni'

# %%
#16
print(math.sin())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(math.sin())
#
# TypeError: math.sin() takes exactly one argument (0 given)

# %%
#17
(1 and not 1)
# Out:
# False

# %%
#18
not (1 or 0)
# Out:
# False

# %%
#18
(not 1) and (not 0)
# Out:
# False

# %%
#18
not(1 and 0)
# Out:
# True

# %%
#18
(not 1) or (not 0)
# Out:
# True

# %%
#19
(0 and 0) or (0 and (not (0)))
# Out:
# 0

# %%
#20
not(not(0) and not(0))
# Out:
# False

# %%
#21
not(not(0) or (not(0)))
# Out:
# False

# %%
#22
(0 and not(1)) or (not(0) and 1)
# Out:
# 1

# %%
#22_1
((math.pow(math.e, 2)) * math.sin(math.pi/6)) + (math.log(3) * math.cos(math.pi/9)) - math.pow(5, 3)
# Out:
# -120.27311408976854

# %%
#22_2
# 𝑁𝑂𝑇(𝑃) 𝐴𝑁𝐷 𝑁𝑂𝑇(𝑄)
not(1) and not(1)
# Out:
# False

# %%
#22_2
#For a = 10 and b = 25; Compute (𝑎<𝑏) 𝐴𝑁𝐷 (𝑎=𝑏)
(10 < 25) and (10 == 25)
# Out:
# False
